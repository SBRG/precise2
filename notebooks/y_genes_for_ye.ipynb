# %% [markdown]
# # Import Packages and Load Data

# %%
from pymodulon.core import IcaData
from pymodulon.plotting import *
from pymodulon.io import load_json_model, save_to_json

# %%
ica_data = load_json_model('../data/precise2/precise2.json.gz')

# %% [markdown]
# # yciT

# %% [markdown]
# ## Gene Expression

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_expression(ica_data, 'yciT', ax=ax)
# Out:
# <AxesSubplot:ylabel='$yciT$ Expression'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_expression(ica_data, 'yciT', projects=['abx_media', 'ompr', 'oxidative', 'tcs', 'ytf2'],
                highlight='ytf2', ax=ax)
# Out:
# <AxesSubplot:ylabel='$yciT$ Expression'>

# %%
ica_data.name2num('yciT')
# Out:
# 'b1284'

# %%
_, ax = plt.subplots()
scatterplot(ica_data.X.loc['b1284'], ica_data.A.loc['YciT'], ax=ax)
ax.set_xlim(-2, 2)
ax.set_ylim(-3, 3)
# Out:
# No handles with labels found to put in legend.
# (-3.0, 3.0)

# %% [markdown]
# What are the conditions when the expression is below -1?
#
# What is the correlation of the remaining points?

# %% [markdown]
# ## iModulon

# %%
plot_gene_weights(ica_data, 'YciT')
# Out:
# <AxesSubplot:xlabel='Gene Start', ylabel='YciT Gene Weight'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_activities(ica_data, 'YciT', ax=ax)
# Out:
# <AxesSubplot:ylabel='YciT iModulon\nActivity'>

# %% [markdown]
# # yfeC

# %% [markdown]
# ## Gene Expression

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_expression(ica_data, 'yfeC', ax=ax)
# Out:
# <AxesSubplot:ylabel='$yfeC$ Expression'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_expression(ica_data, 'yfeC', projects=['abx_media', 'cck_pts', 'pal', 'ssw', 'tcs', 'ytf2'],
                highlight='ytf2', ax=ax)
# Out:
# <AxesSubplot:ylabel='$yfeC$ Expression'>

# %% [markdown]
# ## iModulon

# %%
ica_data.imodulons_with('yfeC')
# Out:
# ['Crp-2', 'ybaQ KO']

# %% [markdown]
# ### Crp-2

# %%
_, ax = plt.subplots(figsize=(20, 8))
plot_expression(ica_data, 'crp', projects='crp', ax=ax)
# Out:
# <AxesSubplot:ylabel='$crp$ Expression'>

# %%
_, ax = plt.subplots()
scatterplot(ica_data.X.loc[ica_data.name2num('crp')], ica_data.A.loc['Crp-2'], ax=ax)
# ax.set_xlim(-2, 2)
# ax.set_ylim(-10, 40)
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:>

# %%
plot_gene_weights(ica_data, 'Crp-2')
# Out:
# <AxesSubplot:xlabel='Gene Start', ylabel='Crp-2 Gene Weight'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_activities(ica_data, 'Crp-2', ax=ax)
# Out:
# <AxesSubplot:ylabel='Crp-2 iModulon\nActivity'>

# %% [markdown]
# ### ybaQ KO

# %%
plot_gene_weights(ica_data, 'ybaQ KO')
# Out:
# <AxesSubplot:xlabel='Gene Start', ylabel='ybaQ KO Gene Weight'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_activities(ica_data, 'ybaQ KO', ax=ax)
# Out:
# <AxesSubplot:ylabel='ybaQ KO iModulon\nActivity'>

# %% [markdown]
# # ygbI

# %% [markdown]
# ## Gene Expression

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_expression(ica_data, 'ygbI', ax=ax)
# Out:
# <AxesSubplot:ylabel='$ygbI$ Expression'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_expression(ica_data, 'ygbI', projects=['abx_media', 'pal', 'ssw', 'tcs'],
                highlight='pal', ax=ax)
# Out:
# <AxesSubplot:ylabel='$ygbI$ Expression'>

# %% [markdown]
# ## iModulon

# %%
_, ax = plt.subplots()
scatterplot(ica_data.X.loc[ica_data.name2num('ygbI')], ica_data.A.loc['YgbI'], ax=ax)
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:>

# %%
plot_gene_weights(ica_data, 'YgbI')
# Out:
# <AxesSubplot:xlabel='Gene Start', ylabel='YgbI Gene Weight'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_activities(ica_data, 'YgbI', ax=ax)
# Out:
# <AxesSubplot:ylabel='YgbI iModulon\nActivity'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_activities(ica_data, 'YgbI', projects='pal', ax=ax)
# Out:
# <AxesSubplot:ylabel='YgbI iModulon\nActivity'>

# %% [markdown]
# # ybcM

# %% [markdown]
# ## Gene Expression

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_expression(ica_data, 'ybcM', ax=ax)
# Out:
# <AxesSubplot:ylabel='$ybcM$ Expression'>

# %%
plot_gene_weights(ica_data, 'DLP12')
# Out:
# <AxesSubplot:xlabel='Gene Start', ylabel='DLP12 Gene Weight'>

# %%
_, ax = plt.subplots(figsize=(20, 6))
plot_activities(ica_data, 'DLP12', ax=ax)
# Out:
# <AxesSubplot:ylabel='DLP12 iModulon\nActivity'>
