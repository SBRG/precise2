# %% [markdown]
# # Import Packages

# %%
from pymodulon.plotting import *
from pymodulon.io import load_json_model, save_to_json

# %% [markdown]
# # Load IcaData object

# %%
ica_data = load_json_model('../data/precise2/precise2.json.gz')

# %% [markdown]
# # Other Regulators

# %%
reg_disc_ims = ica_data.imodulon_table[
    ica_data.imodulon_table['annotation_category'] == 'Regulator Discovery'
].index
reg_disc_ims
# Out:
# Index(['YmfT', 'YgbI', 'YgeV', 'YheO', 'YciT', 'YbaQ', 'PdeL'], dtype='object')

# %%
list(ica_data.view_imodulon('PdeL')['gene_name'])
# Out:
# ['pdeL', 'gsiB', 'gsiC', 'gsiD', 'pdeI', 'dgcI']

# %%
for im in reg_disc_ims:
    plot_activities(ica_data, im)
